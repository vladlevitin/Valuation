# %% [markdown]
# ### Retrieving the Financial Data

# %%
import fitz
import re
import pandas as pd

def read_pdf_file(file_path, start_page=1, end_page=100):
    pdf_document = fitz.open(file_path)
    total_pages = pdf_document.page_count
    pdf_text = ''

    for page_num in range(start_page - 1, end_page):
        pdf_page = pdf_document.load_page(page_num)
        pdf_text += pdf_page.get_text()

    return pdf_text



def format_data(extracted_data):
    data = {}
    lines = extracted_data.split('\n')
    
    for i, line in enumerate(lines):
        numerical_data = re.findall(r'(-?\d{1,3}(?:\s\d{3})*\s\d{3})', line)
        numerical_data = ' '.join(numerical_data).replace(' ', '')
        numerical_data = int(numerical_data) if numerical_data else None
        
        if numerical_data:
            variable_name = None
            
            if i > 0 and not re.search(r'\d', lines[i-1]):
                variable_name = lines[i-1]
            elif i < len(lines) - 1 and not re.search(r'\d', lines[i+1]):
                variable_name = lines[i+1]
            
            if variable_name is not None:
                data[variable_name] = numerical_data
    
    
    split_key_first = 'Årsresultat etter minoritetsinteresser'
    split_key_second = 'Årsresultat'
    
    # check if the first split key is in the data
    
    if split_key_first in data.keys():
        split_key = split_key_first
    else:
        split_key = split_key_second
    
    
    
    keys = list(data.keys())
    split_index = keys.index(split_key) + 1
    
    income_statement, balance_sheet = {k: data[k] for k in keys[:split_index]}, {k: data[k] for k in keys[split_index:]}
    
    return income_statement, balance_sheet


def get_data(file_path, start_page=1, end_page=100):
    extracted_data = read_pdf_file(file_path, start_page, end_page)
    income_statement, balance_sheet = format_data(extracted_data)
    
    return income_statement, balance_sheet

# %%
years = range(2014, 2022)
import json

all_years = {}

for year in years:
    
    input_path = f'elkem_data/pdf/brreg/{year}.pdf'
    output_path = f'elkem_data/json/{year}.json'
    
    income_statement, balance_sheet = get_data(input_path, start_page=6, end_page=11)
    
    with open(output_path, 'w') as f:
        json.dump({'income_statement': income_statement, 'balance_sheet': balance_sheet}, f, indent=4)
    
    all_years[year] = {'income_statement': income_statement, 'balance_sheet': balance_sheet}

with open('elkem_data/json/all_years.json', 'w') as f:
    json.dump(all_years, f, indent=4)

# %%
all_years
# Out:
# {2014: {'income_statement': {'Salgsinntekt': 8561833000,
#    'Annen driftsinntekt': 90519000,
#    'Sum inntekter': 8652352000,
#    'Kostnader': 7788724000,
#    'Varekostnad': 4251156000,
#    'Lønnskostnad': 1358684000,
#    'Avskrivning på varige driftsmidler og immaterielle eiendeler': 394347000,
#    'Nedskrivning av varige driftsmidler og immaterielle eiendeler': 730000,
#    'Other operating expences': 1982864000,
#    'Other gains and losses': 53155000,
#    'Sum kostnader': 8040936000,
#    'Driftsresultat': 611416000,
#    'Finansinntekter og finanskostnader': 417621000,
#    'Inntekt på investering i datterselskap og tilknyttet selskap': -262045000,
#    'Sum finansinntekter': -262045000,
#    'Finance expences net': -42953000,
#    'Sum finanskostnader': -42953000,
#    'Netto finans': -219092000,
#    'Ordinært resultat før skattekostnad': 392324000,
#    'Skattekostnad på ordinært resultat': 169802000,
#    'Ordinært resultat etter skattekostnad': 222522000,
#    'Profit for the year from discontinued operations': 80181000,
#    'Årsresultat': 302703000,
#    'Minoritetsinteresser': 95873000,
#    'Årsresultat etter minoritetsinteresser': 267686000},
#   'balance_sheet': {'Forskning og utvikling': 9123000,
#    'rettigheter': 160884000,
#    'Utsatt skattefordel': 320882000,
#    'Goodwill': 160734000,
#    'Sum immaterielle eiendeler': 642500000,
#    'Varige driftsmidler': 595944000,
#    'Tomter, bygninger og annen fast eiendom': 911210000,
#    'Maskiner og anlegg': 2040947000,
#    'Equipment': 91467000,
#    'Construction in progress': 251012000,
#    'Sum varige driftsmidler': 3294636000,
#    'Finansielle anleggsmidler': 3100763000,
#    'Investeringer i tilknyttet selskap': 960398000,
#    'Investeringer i aksjer og andeler': 53741000,
#    'Derivates': 241155000,
#    'Other non-current assets': 1582274000,
#    'Sum finansielle anleggsmidler': 2666156000,
#    'Sum anleggsmidler': 6603292000,
#    'Omløpsmidler': 3931239000,
#    'Varer': 2086604000,
#    'Sum varer': 2086604000,
#    'Fordringer': 1715245000,
#    'Kundefordringer': 1275377000,
#    'Other current assets': 506421000,
#    'Sum fordringer': 1788642000,
#    'Assets held for sale': 4041698000,
#    'Sum investeringer': 4041698000,
#    'Bankinnskudd, kontanter og lignende': 546114000,
#    'Sum bankinnskudd, kontanter og lignende': 546114000,
#    'Sum omløpsmidler': 4421360000,
#    'SUM EIENDELER': 11024652000,
#    'BALANSE - EGENKAPITAL OG GJELD': 11668099000,
#    'Selskapskapital': 2010000000,
#    'Overkurs': 4045203000,
#    'Sum innskutt egenkapital': 6055203000,
#    'Opptjent egenkapital': 5503413000,
#    'Annen egenkapital': 2606367000,
#    'Sum opptjent egenkapital': 2702240000,
#    'Sum egenkapital': 8757443000,
#    'Gjeld': 7697399000,
#    'Pensjonsforpliktelser': 204450000,
#    'Utsatt skatt': 56595000,
#    'Provisions and other non-current': 157838000,
#    'Sum avsetninger for forpliktelser': 671288000,
#    'Annen langsiktig gjeld': 479317000,
#    'Øvrig langsiktig gjeld': 14520000,
#    'Sum annen langsiktig gjeld': 14520000,
#    'Sum langsiktig gjeld': 685808000,
#    'Kortsiktig gjeld': 498054000,
#    'Gjeld til kredittinstitusjoner': 66425000,
#    'Leverandørgjeld': 831317000,
#    'Betalbar skatt': 43370000,
#    'Other current liabilities': 399134000,
#    'Liabilities held for sale': 1527158000,
#    'Sum kortsiktig gjeld': 1581401000,
#    'Sum gjeld': 2267209000,
#    'SUM EGENKAPITAL OG GJELD': 11024652000}},
#  2015: {'income_statement': {'Salgsinntekt': 14361403000,
#    'Annen driftsinntekt': 179654000,
#    'Sum inntekter': 14541057000,
#    'Kostnader': 12673949000,
#    'Varekostnad': 6847021000,
#    'Lønnskostnad': 2438997000,
#    'Avskrivning på varige driftsmidler og immaterielle eiendeler': 674383000,
#    'Nedskrivning av varige driftsmidler og immaterielle eiendeler': 1813000,
#    'Other operating expences': 3048051000,
#    'Other gains/losses': 65779000,
#    'Sum kostnader': 13076044000,
#    'Driftsresultat': 1465013000,
#    'Finansinntekter og finanskostnader': 577787000,
#    'Income from associates and joint ventures': 21327000,
#    'Finance income': 57492000,
#    'Sum finansinntekter': 78819000,
#    'Foreign exchange gain/losses': -32533000,
#    'Finance expenses': 154067000,
#    'Sum finanskostnader': 121534000,
#    'Netto finans': -42715000,
#    'Ordinært resultat før skattekostnad': 1422298000,
#    'Skattekostnad på ordinært resultat': 462529000,
#    'Ordinært resultat etter skattekostnad': 959769000,
#    'Profit from the year discontinued operations': -7097000,
#    'Årsresultat': 952672000,
#    'Minoritetsinteresser': 123219000,
#    'Årsresultat etter minoritetsinteresser': 919299000},
#   'balance_sheet': {'Other intangible assets': 643493000,
#    'Utsatt skattefordel': 323969000,
#    'Goodwill': 244088000,
#    'Sum immaterielle eiendeler': 1211550000,
#    'Varige driftsmidler': 1208675000,
#    'Tomter, bygninger og annen fast eiendom': 1441970000,
#    'Maskiner og anlegg': 3403958000,
#    'Equipement': 161142000,
#    'Construction in progress': 595138000,
#    'Sum varige driftsmidler': 5602208000,
#    'Finansielle anleggsmidler': 5183162000,
#    'Investeringer i tilknyttet selskap': 67476000,
#    'Investeringer i aksjer og andeler': 96046000,
#    'Derivates': 615208000,
#    'Other non-current assets': 217226000,
#    'Sum finansielle anleggsmidler': 421228000,
#    'Sum anleggsmidler': 7234986000,
#    'Omløpsmidler': 9163870000,
#    'Varer': 3302196000,
#    'Sum varer': 3302196000,
#    'Fordringer': 2896478000,
#    'Kundefordringer': 1864010000,
#    'Andre fordringer': 755737000,
#    'Sum fordringer': 2619747000,
#    'Investeringer': 2691234000,
#    'Sum investeringer': 14332000,
#    'Bankinnskudd, kontanter og lignende': 1305592000,
#    'Sum bankinnskudd, kontanter og lignende': 1305592000,
#    'Sum omløpsmidler': 7241867000,
#    'SUM EIENDELER': 14476853000,
#    'BALANSE - EGENKAPITAL OG GJELD': 15453419000,
#    'Selskapskapital': 2010000000,
#    'Overkurs': 1078203000,
#    'Sum innskutt egenkapital': 3088203000,
#    'Opptjent egenkapital': 6055203000,
#    'Annen egenkapital': 3107336000,
#    'Sum opptjent egenkapital': 3107336000,
#    'Sum egenkapital': 6318758000,
#    'Gjeld': 5675417000,
#    'Pensjonsforpliktelser': 393735000,
#    'Utsatt skatt': 175046000,
#    'Provisions and other non-curent liabilities': 262184000,
#    'Sum avsetninger for forpliktelser': 1554536000,
#    'Annen langsiktig gjeld': 1085922000,
#    'Øvrig langsiktig gjeld': 3051916000,
#    'Sum annen langsiktig gjeld': 3051916000,
#    'Sum langsiktig gjeld': 4606452000,
#    'Kortsiktig gjeld': 2588809000,
#    'Gjeld til kredittinstitusjoner': 327981000,
#    'Leverandørgjeld': 1448578000,
#    'Betalbar skatt': 128496000,
#    'Provisons and other current liabilities': 1031380000,
#    'Sum kortsiktig gjeld': 3551643000,
#    'Sum gjeld': 8158095000,
#    'SUM EGENKAPITAL OG GJELD': 14476853000}},
#  2016: {'income_statement': {'Salgsinntekt': 14045397000,
#    'Annen driftsinntekt': 180772000,
#    'Sum inntekter': 14226169000,
#    'Kostnader': 14541057000,
#    'Varekostnad': 6899039000,
#    'Lønnskostnad': 2559950000,
#    'Avskrivning på varige driftsmidler og immaterielle eiendeler': 717781000,
#    'Nedskrivning av varige driftsmidler og immaterielle eiendeler': 11818000,
#    'Other operating expences': 3149390000,
#    'Other gains / losses': -52438000,
#    'Sum kostnader': 13285540000,
#    'Driftsresultat': 940629000,
#    'Finansinntekter og finanskostnader': 1309786000,
#    'Inntekt på investering i datterselskap og tilknyttet selskap': 22130000,
#    'Annen finansinntekt': 22617000,
#    'Sum finansinntekter': 44747000,
#    'Finance expences': 88501000,
#    'Foreing exchange gains losses': -49662000,
#    'Sum finanskostnader': 38839000,
#    'Netto finans': 5908000,
#    'Ordinært resultat før skattekostnad': 946537000,
#    'Skattekostnad på ordinært resultat': 188568000,
#    'Ordinært resultat etter skattekostnad': 757969000,
#    'Profit for the year from discontinued operations': -7097000,
#    'Årsresultat': 757969000,
#    'Minoritetsinteresser': 87553000,
#    'Årsresultat etter minoritetsinteresser': 721850000},
#   'balance_sheet': {'Other intangible assets': 693013000,
#    'Utsatt skattefordel': 67348000,
#    'Goodwill': 342645000,
#    'Sum immaterielle eiendeler': 1103006000,
#    'Varige driftsmidler': 1211550000,
#    'Tomter, bygninger og annen fast eiendom': 1545154000,
#    'Maskiner og anlegg': 3754746000,
#    'Driftsløsøre, inventar, verktøy, kontormaskiner og lignende': 182526000,
#    'construction in progress': 426661000,
#    'Sum varige driftsmidler': 5909087000,
#    'Finansielle anleggsmidler': 5602208000,
#    'Investeringer i tilknyttet selskap': 108978000,
#    'Investeringer i aksjer og andeler': 100516000,
#    'DErivates': 119161000,
#    'Other non-current assets': 370697000,
#    'Sum finansielle anleggsmidler': 699352000,
#    'Sum anleggsmidler': 7711445000,
#    'Omløpsmidler': 7234986000,
#    'Varer': 3339415000,
#    'Sum varer': 3339415000,
#    'Fordringer': 3302196000,
#    'Kundefordringer': 1870770000,
#    'Andre fordringer': 604656000,
#    'Sum fordringer': 2475426000,
#    'Investeringer': 2619747000,
#    'Derivates': 128001000,
#    'Sum investeringer': 56388000,
#    'Bankinnskudd, kontanter og lignende': 1230668000,
#    'Sum bankinnskudd, kontanter og lignende': 1230668000,
#    'Sum omløpsmidler': 7101897000,
#    'SUM EIENDELER': 14813342000,
#    'BALANSE - EGENKAPITAL OG GJELD': 14476853000,
#    'Selskapskapital': 2010000000,
#    'Overkurs': 1078203000,
#    'Sum innskutt egenkapital': 3088203000,
#    'Opptjent egenkapital': 3088203000,
#    'Annen egenkapital': 4283286000,
#    'Sum opptjent egenkapital': 4370839000,
#    'Sum egenkapital': 7459042000,
#    'Gjeld': 6167047000,
#    'Pensjonsforpliktelser': 425488000,
#    'Utsatt skatt': 114182000,
#    'Provisons and other non-current liabilities': 463560000,
#    'Sum avsetninger for forpliktelser': 1564361000,
#    'Annen langsiktig gjeld': 1706247000,
#    'Øvrig langsiktig gjeld': 2834859000,
#    'Sum annen langsiktig gjeld': 2834859000,
#    'Sum langsiktig gjeld': 4399220000,
#    'Gjeld til kredittinstitusjoner': 277970000,
#    'Leverandørgjeld': 1527587000,
#    'Betalbar skatt': 99387000,
#    'Provisions and other current liabilities': 922135000,
#    'Sum kortsiktig gjeld': 2955080000,
#    'Sum gjeld': 7354300000,
#    'SUM EGENKAPITAL OG GJELD': 14813342000}},
#  2017: {'income_statement': {'Salgsinntekt': 16441894000,
#    'Annen driftsinntekt': 215988000,
#    'Sum inntekter': 16657882000,
#    'Kostnader': 14226169000,
#    'Varekostnad': 8125907000,
#    'Lønnskostnad': 2857634000,
#    'Avskrivning på varige driftsmidler og immaterielle eiendeler': 776023000,
#    'Nedskrivning av varige driftsmidler og immaterielle eiendeler': 16809000,
#    'Other operating expenses': 3575874000,
#    'Other gains and losses': -49313000,
#    'Sum kostnader': 15302934000,
#    'Driftsresultat': 1354948000,
#    'Finansinntekter og finanskostnader': 940629000,
#    'Inntekt på investering i datterselskap og tilknyttet selskap': 34144000,
#    'Annen finansinntekt': 19219000,
#    'Sum finansinntekter': 53363000,
#    'Finance expenses': 119376000,
#    'Foreign exchange gains (losses)': 7701000,
#    'Sum finanskostnader': 127077000,
#    'Netto finans': -73714000,
#    'Ordinært resultat før skattekostnad': 1281234000,
#    'Skattekostnad på ordinært resultat': 269390000,
#    'Ordinært resultat etter skattekostnad': 1011844000,
#    'Årsresultat': 1011844000,
#    'Minoritetsinteresser': 101557000,
#    'Årsresultat etter minoritetsinteresser': 973162000},
#   'balance_sheet': {'Other intangible assets': 719350000,
#    'Utsatt skattefordel': 89584000,
#    'Goodwill': 326323000,
#    'Sum immaterielle eiendeler': 1135257000,
#    'Varige driftsmidler': 1103006000,
#    'Tomter, bygninger og annen fast eiendom': 1569914000,
#    'Maskiner og anlegg': 3775761000,
#    'Equipment': 178690000,
#    'Construction in progress': 1044569000,
#    'Sum varige driftsmidler': 6568934000,
#    'Finansielle anleggsmidler': 5909087000,
#    'Investeringer i tilknyttet selskap': 97871000,
#    'Investeringer i aksjer og andeler': 111967000,
#    'Derivates': 246683000,
#    'Other non-current assets': 324615000,
#    'Sum finansielle anleggsmidler': 686027000,
#    'Sum anleggsmidler': 8390218000,
#    'Omløpsmidler': 7711445000,
#    'Varer': 3561007000,
#    'Sum varer': 3561007000,
#    'Fordringer': 3339415000,
#    'Kundefordringer': 2264479000,
#    'Other current assets': 605595000,
#    'Sum fordringer': 2870074000,
#    'Investeringer': 2475426000,
#    'Sum investeringer': 33357000,
#    'Bankinnskudd, kontanter og lignende': 1493279000,
#    'Sum bankinnskudd, kontanter og lignende': 1493279000,
#    'Sum omløpsmidler': 7957717000,
#    'SUM EIENDELER': 16347935000,
#    'BALANSE - EGENKAPITAL OG GJELD': 14813342000,
#    'Selskapskapital': 2010000000,
#    'Overkurs': 908203000,
#    'Sum innskutt egenkapital': 2918203000,
#    'Opptjent egenkapital': 3088203000,
#    'Annen egenkapital': 5313102000,
#    'Sum opptjent egenkapital': 5313102000,
#    'Sum egenkapital': 8332862000,
#    'Gjeld': 7459042000,
#    'Pensjonsforpliktelser': 444807000,
#    'Utsatt skatt': 104587000,
#    'Provisions and other non-current liabilities': 389859000,
#    'Sum avsetninger for forpliktelser': 1318208000,
#    'Annen langsiktig gjeld': 1564361000,
#    'Gjeld til kredittinstitusjoner': 661189000,
#    'Sum annen langsiktig gjeld': 2681975000,
#    'Sum langsiktig gjeld': 4000183000,
#    'Kortsiktig gjeld': 4399220000,
#    'Leverandørgjeld': 1836888000,
#    'Betalbar skatt': 138668000,
#    'Provisions and other current liabilities': 1131462000,
#    'Sum kortsiktig gjeld': 4014890000,
#    'Sum gjeld': 8015073000,
#    'SUM EGENKAPITAL OG GJELD': 16347935000}},
#  2018: {'income_statement': {'Salgsinntekt': 25625000000,
#    'Other operating income': 244000000,
#    'Share of profit from equity accounted companies': 18000000,
#    'Sum inntekter': 25887000000,
#    'Kostnader': 21403000000,
#    'Varekostnad': 12023000000,
#    'Lønnskostnad': 3449000000,
#    'Avskrivning på varige driftsmidler og immaterielle eiendeler': 1263000000,
#    'Nedskrivning av varige driftsmidler og immaterielle eiendeler': 8000000,
#    'Other operating expenses': 4622000000,
#    'Other gains and losses': 380000000,
#    'Sum kostnader': 21745000000,
#    'Driftsresultat': 4142000000,
#    'Finansinntekter og finanskostnader': 1971000000,
#    'Share of profit from equity accounted financial investments': -23000000,
#    'Annen finansinntekt': 42000000,
#    'Sum finansinntekter': 19000000,
#    'Finance expenses': 388000000,
#    'Foreign exchange gains (losses)': -19000000,
#    'Sum finanskostnader': 369000000,
#    'Netto finans': -350000000,
#    'Ordinært resultat før skattekostnad': 3792000000,
#    'Skattekostnad på ordinært resultat': 425000000,
#    'Ordinært resultat etter skattekostnad': 3367000000,
#    'Årsresultat': 3367000000},
#   'balance_sheet': {'Other intangible assets': 922000000,
#    'Utsatt skattefordel': 60000000,
#    'Goodwill': 342000000,
#    'Sum immaterielle eiendeler': 1324000000,
#    'Varige driftsmidler': 1327000000,
#    'Property, plant and equipment': 12445000000,
#    'Sum varige driftsmidler': 12445000000,
#    'Finansielle anleggsmidler': 11950000000,
#    'Investeringer i tilknyttet selskap': 134000000,
#    'Derivatives': 79000000,
#    'Other non-current assets': 440000000,
#    'Sum finansielle anleggsmidler': 705000000,
#    'Sum anleggsmidler': 14474000000,
#    'Omløpsmidler': 13995000000,
#    'Varer': 5467000000,
#    'Sum varer': 5467000000,
#    'Fordringer': 4099000000,
#    'Kundefordringer': 2391000000,
#    'Other current assets': 836000000,
#    'Sum fordringer': 3227000000,
#    'Investeringer': 4609000000,
#    'Sum investeringer': 303000000,
#    'Bankinnskudd, kontanter og lignende': 33000000,
#    'Restricted deposits': 577000000,
#    'Cash and cash equivalents': 7081000000,
#    'Sum bankinnskudd, kontanter og lignende': 7658000000,
#    'Sum omløpsmidler': 16655000000,
#    'SUM EIENDELER': 31129000000,
#    'BALANSE - EGENKAPITAL OG GJELD': 25507000000,
#    'Selskapskapital': 2907000000,
#    'Overkurs': 5195000000,
#    'Sum innskutt egenkapital': 8102000000,
#    'Opptjent egenkapital': 2918000000,
#    'Annen egenkapital': 5519000000,
#    'Minoritetsinteresser': 101000000,
#    'Sum opptjent egenkapital': 5620000000,
#    'Sum egenkapital': 13722000000,
#    'Gjeld': 8565000000,
#    'Utsatt skatt': 207000000,
#    'Employee benefit obligations': 671000000,
#    'Provisions and other non-current liabilities': 232000000,
#    'Sum avsetninger for forpliktelser': 1452000000,
#    'Annen langsiktig gjeld': 1355000000,
#    'Gjeld til kredittinstitusjoner': 2052000000,
#    'Sum annen langsiktig gjeld': 7131000000,
#    'Sum langsiktig gjeld': 8583000000,
#    'Kortsiktig gjeld': 5940000000,
#    'Leverandørgjeld': 2731000000,
#    'Betalbar skatt': 330000000,
#    'Bills payable': 1740000000,
#    'Provisions and other current liabilities': 1221000000,
#    'Sum kortsiktig gjeld': 8824000000,
#    'Sum gjeld': 17407000000,
#    'SUM EGENKAPITAL OG GJELD': 31129000000}},
#  2019: {'income_statement': {'Salgsinntekt': 22246000000,
#    'Other operating income': 391000000,
#    'Share of profit (loss) from equity accounted companies': 31000000,
#    'Sum inntekter': 22668000000,
#    'Kostnader': 25230000000,
#    'Varekostnad': 11512000000,
#    'Lønnskostnad': 3696000000,
#    'Avskrivning på varige driftsmidler og immaterielle eiendeler': 1456000000,
#    'Nedskrivning av varige driftsmidler og immaterielle eiendeler': 11000000,
#    'Other operating expenses': 4804000000,
#    'Other items': -195000000,
#    'Sum kostnader': 21284000000,
#    'Driftsresultat': 1384000000,
#    'Finansinntekter og finanskostnader': 4142000000,
#    'Share of profit from equity accounted companies': -12000000,
#    'Annen finansinntekt': 41000000,
#    'Sum finansinntekter': 29000000,
#    'Finance expenses': 295000000,
#    'Foreign exchange gains (losses)': -16000000,
#    'Sum finanskostnader': 279000000,
#    'Netto finans': -250000000,
#    'Ordinært resultat før skattekostnad': 1134000000,
#    'Skattekostnad på ordinært resultat': 237000000,
#    'Ordinært resultat etter skattekostnad': 897000000,
#    'Årsresultat': 897000000},
#   'balance_sheet': {'Other intangibles': 777000000,
#    'Utsatt skattefordel': 66000000,
#    'Goodwill': 466000000,
#    'Sum immaterielle eiendeler': 1309000000,
#    'Varige driftsmidler': 1324000000,
#    'Property, plant and equipment': 13202000000,
#    'Right-of-use-assets': 580000000,
#    'Sum varige driftsmidler': 13782000000,
#    'Finansielle anleggsmidler': 12445000000,
#    'Investeringer i tilknyttet selskap': 129000000,
#    'Derivatives': 37000000,
#    'Other assets': 406000000,
#    'Sum finansielle anleggsmidler': 601000000,
#    'Sum anleggsmidler': 15692000000,
#    'Omløpsmidler': 14474000000,
#    'Varer': 5224000000,
#    'Sum varer': 5224000000,
#    'Fordringer': 5467000000,
#    'Kundefordringer': 2269000000,
#    'Othe assets': 1014000000,
#    'Sum fordringer': 3283000000,
#    'Investeringer': 3226000000,
#    'Sum investeringer': 38000000,
#    'Bankinnskudd, kontanter og lignende': 303000000,
#    'Restricted deposits': 271000000,
#    'Cash and cash equivalents': 4496000000,
#    'Sum bankinnskudd, kontanter og lignende': 4767000000,
#    'Sum omløpsmidler': 13312000000,
#    'SUM EIENDELER': 29004000000,
#    'BALANSE - EGENKAPITAL OG GJELD': 31129000000,
#    'Selskapskapital': 2907000000,
#    'Overkurs': 3709000000,
#    'Sum innskutt egenkapital': 6616000000,
#    'Opptjent egenkapital': 8102000000,
#    'Annen egenkapital': 6240000000,
#    'Minoritetsinteresser': 96000000,
#    'Sum opptjent egenkapital': 6336000000,
#    'Sum egenkapital': 12952000000,
#    'Gjeld': 13722000000,
#    'Utsatt skatt': 243000000,
#    'Employee benefit obligations': 640000000,
#    'Provisions and other non-current lia': 159000000,
#    'Sum avsetninger for forpliktelser': 1196000000,
#    'Annen langsiktig gjeld': 1452000000,
#    'Gjeld til kredittinstitusjoner': 1262000000,
#    'Sum annen langsiktig gjeld': 8340000000,
#    'Sum langsiktig gjeld': 9536000000,
#    'Kortsiktig gjeld': 8583000000,
#    'Leverandørgjeld': 2767000000,
#    'Betalbar skatt': 51000000,
#    'Bills payable': 887000000,
#    'Provisions and other current liabilitie': 872000000,
#    'Sum kortsiktig gjeld': 6516000000,
#    'Sum gjeld': 16052000000,
#    'SUM EGENKAPITAL OG GJELD': 29004000000}},
#  2020: {'income_statement': {'Salgsinntekt': 24025000000,
#    'Annen driftsinntekt': 631000000,
#    'Share of profit (loss) from equity accounted companies': 35000000,
#    'Sum inntekter': 24691000000,
#    'Kostnader': 22668000000,
#    'Varekostnad': 12858000000,
#    'Lønnskostnad': 4028000000,
#    'Avskrivning på varige driftsmidler og immaterielle eiendeler': 1710000000,
#    'Nedskrivning av varige driftsmidler og immaterielle eiendeler': 17000000,
#    'Annen driftskostnad': 5121000000,
#    'Other items': 130000000,
#    'Sum kostnader': 23864000000,
#    'Driftsresultat': 827000000,
#    'Finansinntekter og finanskostnader': 1384000000,
#    'Inntekt på investering i datterselskap og tilknyttet selskap': -15000000,
#    'Annen finansinntekt': 31000000,
#    'Sum finansinntekter': 16000000,
#    'Annen finanskostnad': 278000000,
#    'Foreign exchange gains (losses)': -19000000,
#    'Sum finanskostnader': 259000000,
#    'Netto finans': -243000000,
#    'Ordinært resultat før skattekostnad': 584000000,
#    'Skattekostnad på ordinært resultat': 306000000,
#    'Ordinært resultat etter skattekostnad': 278000000,
#    'Årsresultat': 278000000},
#   'balance_sheet': {'Utsatt skattefordel': 96000000,
#    'Goodwill': 919000000,
#    'Other intangible assets': 1319000000,
#    'Sum immaterielle eiendeler': 2334000000,
#    'Varige driftsmidler': 1309000000,
#    'Property, plant and equipment': 14131000000,
#    'Right-of-use assets': 875000000,
#    'Sum varige driftsmidler': 15006000000,
#    'Finansielle anleggsmidler': 13782000000,
#    'Investments in equity accounted companies': 183000000,
#    'Derivatives': 101000000,
#    'Other assets': 1212000000,
#    'Sum finansielle anleggsmidler': 675000000,
#    'Sum anleggsmidler': 18015000000,
#    'Omløpsmidler': 15692000000,
#    'Varer': 5241000000,
#    'Sum varer': 5241000000,
#    'Fordringer': 5224000000,
#    'Kundefordringer': 2796000000,
#    'Restricted deposits': 322000000,
#    'Sum fordringer': 4478000000,
#    'Bankinnskudd, kontanter og lignende': 3154000000,
#    'Sum bankinnskudd, kontanter og lignende': 3154000000,
#    'Sum omløpsmidler': 12873000000,
#    'SUM EIENDELER': 30888000000,
#    'BALANSE - EGENKAPITAL OG GJELD': 29004000000,
#    'Selskapskapital': 2907000000,
#    'Other paid in capital': 3389000000,
#    'Sum innskutt egenkapital': 6296000000,
#    'Opptjent egenkapital': 6616000000,
#    'Annen egenkapital': 6231000000,
#    'Minoritetsinteresser': 108000000,
#    'Sum opptjent egenkapital': 6339000000,
#    'Sum egenkapital': 12635000000,
#    'Gjeld': 12952000000,
#    'Utsatt skatt': 336000000,
#    'Sum avsetninger for forpliktelser': 336000000,
#    'Annen langsiktig gjeld': 243000000,
#    'Gjeld til kredittinstitusjoner': 3292000000,
#    'Employee benefit obligations': 740000000,
#    'Provisions and other liabilities': 1063000000,
#    'Sum annen langsiktig gjeld': 8446000000,
#    'Sum langsiktig gjeld': 8782000000,
#    'Kortsiktig gjeld': 9536000000,
#    'Leverandørgjeld': 3157000000,
#    'Betalbar skatt': 65000000,
#    'Bills payable': 1053000000,
#    'Sum kortsiktig gjeld': 9471000000,
#    'Sum gjeld': 18253000000,
#    'SUM EGENKAPITAL OG GJELD': 30888000000}},
#  2021: {'income_statement': {'Revenue': 33083000000,
#    'Other operating income': 586000000,
#    'Share of profit (loss) from equity accounted companies': 48000000,
#    'Sum inntekter': 33717000000,
#    'Kostnader': 24691000000,
#    'Raw materials and energy for production': 15861000000,
#    'Employee benefit expenses': 4530000000,
#    'Amortisation and depreciation': 1816000000,
#    'Impairment losses': 76000000,
#    'Other operating expenses': 5536000000,
#    'Other items': 113000000,
#    'Sum kostnader': 27932000000,
#    'Driftsresultat': 5785000000,
#    'Finansinntekter og finanskostnader': 827000000,
#    'Share of profit (loss) from equity accounted financial investments': 37000000,
#    'Finance income': 40000000,
#    'Sum finansinntekter': 77000000,
#    'Finance expenses': 276000000,
#    'Foreign exchange gains (losses)': -241000000,
#    'Sum finanskostnader': 35000000,
#    'Netto finans': 42000000,
#    'Ordinært resultat før skattekostnad': 5827000000,
#    'Income tax (expense) benefit': 1163000000,
#    'Ordinært resultat etter skattekostnad': 4664000000,
#    'Årsresultat': 4664000000},
#   'balance_sheet': {'Other intagible assets': 1602000000,
#    'Utsatt skattefordel': 48000000,
#    'Goodwill': 941000000,
#    'Sum immaterielle eiendeler': 2591000000,
#    'Varige driftsmidler': 2334000000,
#    'Property, plant and equipment': 15722000000,
#    'Right-of-use assets': 1017000000,
#    'Sum varige driftsmidler': 16739000000,
#    'Finansielle anleggsmidler': 15006000000,
#    'Investements in qeuity accounted companies': 241000000,
#    'Derivatives': 23000000,
#    'Other assets': 1552000000,
#    'Sum finansielle anleggsmidler': 1023000000,
#    'Sum anleggsmidler': 20353000000,
#    'Omløpsmidler': 18014000000,
#    'Inventories': 7716000000,
#    'Sum varer': 7716000000,
#    'Fordringer': 5241000000,
#    'Trade receivables': 4297000000,
#    'Sum fordringer': 6132000000,
#    'Bankinnskudd, kontanter og lignende': 4157000000,
#    'Restricted deposits': 609000000,
#    'Cash and cash equivalents': 7040000000,
#    'Sum bankinnskudd, kontanter og lignende': 7649000000,
#    'Sum omløpsmidler': 21497000000,
#    'SUM EIENDELER': 41850000000,
#    'BALANSE - EGENKAPITAL OG GJELD': 30888000000,
#    'Paid-in capita': 8097000000,
#    'Sum innskutt egenkapital': 8097000000,
#    'Opptjent egenkapital': 6296000000,
#    'Retained earnings': 11692000000,
#    'Minoritetsinteresser': 86000000,
#    'Sum opptjent egenkapital': 11778000000,
#    'Sum egenkapital': 19875000000,
#    'Gjeld': 12636000000,
#    'Utsatt skatt': 505000000,
#    'Employee benefit obligations': 976000000,
#    'Provisions and other liabilities': 1655000000,
#    'Sum avsetninger for forpliktelser': 1316000000,
#    'Annen langsiktig gjeld': 1593000000,
#    'Interest-bearing liabilities': 1972000000,
#    'Sum annen langsiktig gjeld': 8409000000,
#    'Sum langsiktig gjeld': 9725000000,
#    'Kortsiktig gjeld': 8782000000,
#    'Bills payable': 2096000000,
#    'Leverandørgjeld': 4614000000,
#    'Income tax payables': 914000000,
#    'Sum kortsiktig gjeld': 12250000000,
#    'Sum gjeld': 21975000000,
#    'SUM EGENKAPITAL OG GJELD': 41850000000}}}

# %% [markdown]
# ### Formatting

# %%
import json



translation_mapping = {
"Salgsinntekt": "Revenue",
"Annen driftsinntekt": "Other operating income",
"Kostnader": "Expenses",
"Varekostnad": "Cost of goods sold",
"Lønnskostnad": "Employee benefit expenses",
"Avskrivning på varige driftsmidler og immaterielle eiendeler": "Amortisation and depreciation",
"Nedskrivning av varige driftsmidler og immaterielle eiendeler": "Impairment losses",
"Annen driftskostnad": "Other operating expenses",
"Driftsresultat": "Operating profit",
"Finansinntekter og finanskostnader": "Finance income and expenses",
"Annen finansinntekt": "Finance income",
"Sum finansinntekter": "Total finance income",
"Annen finanskostnad": "Finance expenses",
"Netto finans": "Net finance",
"Ordinært resultat før skattekostnad": "Profit before tax",
"Skattekostnad på ordinært resultat": "Income tax (expense) benefit",
"Ordinært resultat etter skattekostnad": "Profit after tax",
"Årsresultat": "Annual profit",
"Sum inntekter": "Total revenue",
"Sum kostnader": "Total expenses",
"Sum finansinntekter og finanskostnader": "Total finance income and expenses",
"Inntekt på investering i datterselskap og tilknyttet selskap" : "Income from investments in subsidiaries and associated companies",
"Sum finanskostnader": "Total finance expenses",
"Årsresultat etter minoritetsinteresser" : "Annual profit after minority interests",


"Utsatt skattefordel": "Deferred tax asset",
"Goodwill": "Goodwill",
"Other intangible assets": "Other intangible assets",
"Sum immaterielle eiendeler": "Total intangible assets",
"Varige driftsmidler": "Tangible fixed assets",
"Property, plant and equipment": "Property, plant and equipment",
"Right-of-use assets": "Right-of-use assets",
"Sum varige driftsmidler": "Total tangible fixed assets",
"Finansielle anleggsmidler": "Financial fixed assets",
"Investments in equity accounted companies": "Investments in equity accounted companies",
"Derivatives": "Derivatives",
"Other assets": "Other assets",
"Sum finansielle anleggsmidler": "Total financial fixed assets",
"Sum anleggsmidler": "Total fixed assets",
"Omløpsmidler": "Current assets",
"Varer": "Inventories",
"Sum varer": "Total inventories",
"Fordringer": "Receivables",
"Kundefordringer": "Trade receivables",
"Restricted deposits": "Restricted deposits",
"Sum fordringer": "Total receivables",
"Bankinnskudd, kontanter og lignende": "Cash and cash equivalents",
"Sum bankinnskudd, kontanter og lignende": "Total cash and cash equivalents",
"Sum omløpsmidler": "Total current assets",
"SUM EIENDELER": "TOTAL ASSETS",
"BALANSE - EGENKAPITAL OG GJELD": "BALANCE - EQUITY AND LIABILITIES",
"Selskapskapital": "Share capital",
"Other paid in capital": "Other paid in capital",
"Sum innskutt egenkapital": "Total contributed equity",
"Opptjent egenkapital": "Retained earnings",
"Annen egenkapital": "Other equity",
"Minoritetsinteresser": "Minority interests",
"Sum opptjent egenkapital": "Total retained earnings",
"Sum egenkapital": "Total equity",
"Gjeld": "Debt",
"Utsatt skatt": "Deferred tax",
"Sum avsetninger for forpliktelser": "Total provisions for liabilities",
"Annen langsiktig gjeld": "Other long-term debt",
"Gjeld til kredittinstitusjoner": "Debt to credit institutions",
"Employee benefit obligations": "Employee benefit obligations",
"Provisions and other liabilities": "Provisions and other liabilities",
"Sum annen langsiktig gjeld": "Total other long-term debt",
"Sum langsiktig gjeld": "Total long-term debt",
"Kortsiktig gjeld": "Short-term debt",
"Leverandørgjeld": "Accounts payable",
"Betalbar skatt": "Income tax payable",
"Bills payable": "Bills payable",
"Sum kortsiktig gjeld": "Total short-term debt",
"Sum gjeld": "Total debt",
"SUM EGENKAPITAL OG GJELD": "TOTAL EQUITY AND LIABILITIES",
"Paid-in capita": "Paid-in capital",
"Inventories": "Inventories",
"Trade receivables": "Trade receivables",
"Bankinnskudd, kontanter og lignende": "Cash and cash equivalents",
"Restricted deposits": "Restricted deposits",
"Cash and cash equivalents": "Cash and cash equivalents",
"Income tax payables": "Income tax payables",
"Interest-bearing liabilities": "Interest-bearing liabilities",
"Investements in qeuity accounted companies": "Investments in equity accounted companies",
"Pensjonsforpliktelser": "Pension obligations",
"Øvrig langsiktig gjeld": "Other long-term debt",
"Forskning og utvikling": "Research and development",
"rettigheter": "Concessions, patents, licenses, trademarks and similar rights",
"Sum investeringer": "Total investments",
"Tomter, bygninger og annen fast eiendom": "Land, buildings and other fixed assets",

}



def translate_data(data, translation_mapping):
    translated_data = {}

    for key, value in data.items():
        if key in translation_mapping:
            translated_key = translation_mapping[key]
            translated_data[translated_key] = value
        else:
            translated_data[key] = value

    return translated_data

def translate_financial_statements(year_data, translation_mapping):
    translated_year_data = {
        year: {
            financial_statement: translate_data(data, translation_mapping)
            for financial_statement, data in year_data.items()
        }
        for year, year_data in year_data.items()
    }

    return translated_year_data


with open('elkem_data/json/all_years.json', 'w') as f:
    json.dump(all_years, f, indent=4)

# %%
import json

input_json = all_years

# Extract income statement and balance sheet keys for the year 2021
years = set(input_json.keys())
format_year = max(years)

years.remove(format_year)

income_statement_keys = list(input_json[format_year]["income_statement"].keys())
balance_sheet_keys = list(input_json[format_year]["balance_sheet"].keys())

formatted_json = {}



for year in sorted(years):
    formatted_json[year] = {
        "income_statement": {},
        "balance_sheet": {},
    }

    for key in income_statement_keys:
        if key in input_json[year]["income_statement"]:
            formatted_json[year]["income_statement"][key] = input_json[year]["income_statement"][key]

    for key in balance_sheet_keys:
        if key in input_json[year]["balance_sheet"]:
            formatted_json[year]["balance_sheet"][key] = input_json[year]["balance_sheet"][key]

# Add the year 2021 data as it is
formatted_json[format_year] = input_json[format_year]

# order the year keys in the JSON

formatted_json

# Save the formatted JSON to a new file
with open("elkem_data/json/all_years_formatted.json", "w") as outfile:
    json.dump(formatted_json, outfile, indent=4)

# %%
import pandas as pd
import json

json_data = all_years

def json_to_dataframes(json_data):
    data = json_data

    income_statements = {}
    balance_sheets = {}

    for year, content in data.items():
        income_statements[year] = content["income_statement"]
        balance_sheets[year] = content["balance_sheet"]

    income_statement_df = pd.DataFrame(income_statements)
    balance_sheet_df = pd.DataFrame(balance_sheets)

    return income_statement_df, balance_sheet_df

income_statement_df, balance_sheet_df = json_to_dataframes(json_data)

income_statement_df
balance_sheet_df
# Out:
#                                                            2014          2015
# Research and development                              9123000.0           NaN  \
# Concessions, patents, licenses, trademarks and ...  160884000.0           NaN
# Deferred tax asset                                  320882000.0  3.239690e+08
# Goodwill                                            160734000.0  2.440880e+08
# Total intangible assets                             642500000.0  1.211550e+09
# ...                                                         ...           ...
# Provisions and other liabilities                            NaN           NaN
# Other intagible assets                                      NaN           NaN
# Paid-in capital                                             NaN           NaN
# Interest-bearing liabilities                                NaN           NaN
# Income tax payables                                         NaN           NaN
#
#                                                             2016
# Research and development                                     NaN  \
# Concessions, patents, licenses, trademarks and ...           NaN
# Deferred tax asset                                  6.734800e+07
# Goodwill                                            3.426450e+08
# Total intangible assets                             1.103006e+09
# ...                                                          ...
# Provisions and other liabilities                             NaN
# Other intagible assets                                       NaN
# Paid-in capital                                              NaN
# Interest-bearing liabilities                                 NaN
# Income tax payables                                          NaN
#
#                                                             2017
# Research and development                                     NaN  \
# Concessions, patents, licenses, trademarks and ...           NaN
# Deferred tax asset                                  8.958400e+07
# Goodwill                                            3.263230e+08
# Total intangible assets                             1.135257e+09
# ...                                                          ...
# Provisions and other liabilities                             NaN
# Other intagible assets                                       NaN
# Paid-in capital                                              NaN
# Interest-bearing liabilities                                 NaN
# Income tax payables                                          NaN
#
#                                                             2018
# Research and development                                     NaN  \
# Concessions, patents, licenses, trademarks and ...           NaN
# Deferred tax asset                                  6.000000e+07
# Goodwill                                            3.420000e+08
# Total intangible assets                             1.324000e+09
# ...                                                          ...
# Provisions and other liabilities                             NaN
# Other intagible assets                                       NaN
# Paid-in capital                                              NaN
# Interest-bearing liabilities                                 NaN
# Income tax payables                                          NaN
#
#                                                             2019
# Research and development                                     NaN  \
# Concessions, patents, licenses, trademarks and ...           NaN
# Deferred tax asset                                  6.600000e+07
# Goodwill                                            4.660000e+08
# Total intangible assets                             1.309000e+09
# ...                                                          ...
# Provisions and other liabilities                             NaN
# Other intagible assets                                       NaN
# Paid-in capital                                              NaN
# Interest-bearing liabilities                                 NaN
# Income tax payables                                          NaN
#
#                                                             2020          2021
# Research and development                                     NaN           NaN
# Concessions, patents, licenses, trademarks and ...           NaN           NaN
# Deferred tax asset                                  9.600000e+07  4.800000e+07
# Goodwill                                            9.190000e+08  9.410000e+08
# Total intangible assets                             2.334000e+09  2.591000e+09
# ...                                                          ...           ...
# Provisions and other liabilities                    1.063000e+09  1.655000e+09
# Other intagible assets                                       NaN  1.602000e+09
# Paid-in capital                                              NaN  8.097000e+09
# Interest-bearing liabilities                                 NaN  1.972000e+09
# Income tax payables                                          NaN  9.140000e+08
#
# [88 rows x 8 columns]

# %% [markdown]
# ### Saving to Excel

# %%
import json
import pandas as pd
from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows

all_years = json.load(open('elkem_data/json/all_years_formatted.json'))


workbook = Workbook()
workbook.remove(workbook.active)

# Create Income Statement and Balance Sheet worksheets
income_statement_ws = workbook.create_sheet('Income Statements')
balance_sheet_ws = workbook.create_sheet('Balance Sheets')

combined_income_statement_ws = workbook.create_sheet('Combined Income Statements')
combined_balance_sheet_ws = workbook.create_sheet('Combined Balance Sheets')


# write the income_statement_df and balance_sheet_df to excel

com

current_col = 1

for year in all_years:
    income_statement_df = pd.DataFrame(all_years[year]['income_statement'].items(), columns=['Variable', 'Value'])
    balance_sheet_df = pd.DataFrame(all_years[year]['balance_sheet'].items(), columns=['Variable', 'Value'])
    
    income_statement_ws.cell(row=1, column=current_col, value=f"Income Statement {year}")
    
    for r, row in enumerate(dataframe_to_rows(income_statement_df, index=False, header=True)):
        for c, cell_value in enumerate(row):
            income_statement_ws.cell(row=r + 2, column=current_col + c, value=cell_value)

    balance_sheet_ws.cell(row=1, column=current_col, value=f"Balance Sheet {year}")
    
    for r, row in enumerate(dataframe_to_rows(balance_sheet_df, index=False, header=True)):
        for c, cell_value in enumerate(row):
            balance_sheet_ws.cell(row=r + 2, column=current_col + c, value=cell_value)

    # Update the current column with a 1 column gap between tables
    current_col += len(income_statement_df.columns) + 1

# Save the Excel workbook
workbook.save('elkem_financial_data.xlsx')
